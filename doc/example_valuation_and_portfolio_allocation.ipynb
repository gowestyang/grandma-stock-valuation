# %%
from grandma_stock_valuation import FileLogger, YahooDataLoader, batchValuation, addCashPortfolio, allocatePortfolio
import time

logger = FileLogger()
logPrint = logger.log_pandas

# %% [markdown]
# ### Refresh data of each instrument

# %%
d_instrument = {
    'IVV':'SP500',
    '3073.HK':'Greater China',
    'VPL':'Developed Asia-Pacific',
    'IEV':'Europe',
    'ASEA':'SE Asia',

    'XT':'Global Tech',
    'IXG':'Global Finance',
    'IXJ':'Global Healthcare',
    'KXI':'Global Consumer Staple',
    'RXI':'Global Consumer Discretionary',

    'AAXJ':'Asia ex Japan',
    'EZU':'Eurozone'
}

d_instrument_data = {}
for ticker, name in d_instrument.items():
    logPrint(f"{ticker}: {name}")

    # Refresh data
    yahoo = YahooDataLoader(ticker, verbose=0, printfunc=logPrint)
    df = yahoo.queryEOD(save=True)

    d_instrument_data[ticker] = df
    time.sleep(1)
# Out:
# 2022-02-18 14:47:14,484 INFO IVV: SP500
# 2022-02-18 14:47:14,485 INFO IVV: Existing EOD data file found at __data__\IVV_EOD.csv.gz.
# 2022-02-18 14:47:14,502 INFO IVV: Existing EOD data file contains 5473 rows over 5473 dates from 2000-05-19 to 2022-02-17.
# 2022-02-18 14:47:14,611 INFO IVV: Queried EOD data contains 1 rows over 1 dates from 2022-02-17 to 2022-02-17.
# 2022-02-18 14:47:14,616 INFO IVV: Amended data file contains 5473 rows over 5473 dates from 2000-05-19 to 2022-02-17.
# 2022-02-18 14:47:15,743 INFO 3073.HK: Greater China
# 2022-02-18 14:47:15,745 INFO 3073.HK: Existing EOD data file found at __data__\3073.HK_EOD.csv.gz.
# 2022-02-18 14:47:15,753 INFO 3073.HK: Existing EOD data file contains 2817 rows over 2817 dates from 2010-09-15 to 2022-02-18.
# 2022-02-18 14:47:15,835 ERROR 3073.HK: Failed to query EOD data!
# 2022-02-18 14:47:15,836 WARNING 3073.HK: No new data to refresh.
# 2022-02-18 14:47:16,846 INFO VPL: Developed Asia-Pacific
# 2022-02-18 14:47:16,848 INFO VPL: Existing EOD data file found at __data__\VPL_EOD.csv.gz.
# 2022-02-18 14:47:16,859 INFO VPL: Existing EOD data file contains 4267 rows over 4267 dates from 2005-03-10 to 2022-02-17.
# 2022-02-18 14:47:16,939 INFO VPL: Queried EOD data contains 1 rows over 1 dates from 2022-02-17 to 2022-02-17.
# 2022-02-18 14:47:16,942 INFO VPL: Amended data file contains 4267 rows over 4267 dates from 2005-03-10 to 2022-02-17.
# 2022-02-18 14:47:18,049 INFO IEV: Europe
# 2022-02-18 14:47:18,050 INFO IEV: Existing EOD data file found at __data__\IEV_EOD.csv.gz.
# 2022-02-18 14:47:18,064 INFO IEV: Existing EOD data file contains 5425 rows over 5425 dates from 2000-07-28 to 2022-02-17.
# 2022-02-18 14:47:18,150 INFO IEV: Queried EOD data contains 1 rows over 1 dates from 2022-02-17 to 2022-02-17.
# 2022-02-18 14:47:18,156 INFO IEV: Amended data file contains 5425 rows over 5425 dates from 2000-07-28 to 2022-02-17.
# 2022-02-18 14:47:19,272 INFO ASEA: SE Asia
# 2022-02-18 14:47:19,272 INFO ASEA: Existing EOD data file found at __data__\ASEA_EOD.csv.gz.
# 2022-02-18 14:47:19,281 INFO ASEA: Existing EOD data file contains 2770 rows over 2770 dates from 2011-02-17 to 2022-02-17.
# 2022-02-18 14:47:19,371 INFO ASEA: Queried EOD data contains 1 rows over 1 dates from 2022-02-17 to 2022-02-17.
# 2022-02-18 14:47:19,375 INFO ASEA: Amended data file contains 2770 rows over 2770 dates from 2011-02-17 to 2022-02-17.
# 2022-02-18 14:47:20,446 INFO XT: Global Tech
# 2022-02-18 14:47:20,447 INFO XT: Existing EOD data file found at __data__\XT_EOD.csv.gz.
# 2022-02-18 14:47:20,454 INFO XT: Existing EOD data file contains 1742 rows over 1742 dates from 2015-03-23 to 2022-02-17.
# 2022-02-18 14:47:20,526 INFO XT: Queried EOD data contains 1 rows over 1 dates from 2022-02-17 to 2022-02-17.
# 2022-02-18 14:47:20,530 INFO XT: Amended data file contains 1742 rows over 1742 dates from 2015-03-23 to 2022-02-17.
# 2022-02-18 14:47:21,582 INFO IXG: Global Finance
# 2022-02-18 14:47:21,583 INFO IXG: Existing EOD data file found at __data__\IXG_EOD.csv.gz.
# 2022-02-18 14:47:21,596 INFO IXG: Existing EOD data file contains 5094 rows over 5094 dates from 2001-11-26 to 2022-02-17.
# 2022-02-18 14:47:21,693 INFO IXG: Queried EOD data contains 1 rows over 1 dates from 2022-02-17 to 2022-02-17.
# 2022-02-18 14:47:21,697 INFO IXG: Amended data file contains 5094 rows over 5094 dates from 2001-11-26 to 2022-02-17.
# 2022-02-18 14:47:22,826 INFO IXJ: Global Healthcare
# 2022-02-18 14:47:22,828 INFO IXJ: Existing EOD data file found at __data__\IXJ_EOD.csv.gz.
# 2022-02-18 14:47:22,842 INFO IXJ: Existing EOD data file contains 5094 rows over 5094 dates from 2001-11-26 to 2022-02-17.
# 2022-02-18 14:47:22,926 INFO IXJ: Queried EOD data contains 1 rows over 1 dates from 2022-02-17 to 2022-02-17.
# 2022-02-18 14:47:22,930 INFO IXJ: Amended data file contains 5094 rows over 5094 dates from 2001-11-26 to 2022-02-17.
# 2022-02-18 14:47:24,041 INFO KXI: Global Consumer Staple
# 2022-02-18 14:47:24,043 INFO KXI: Existing EOD data file found at __data__\KXI_EOD.csv.gz.
# 2022-02-18 14:47:24,055 INFO KXI: Existing EOD data file contains 3879 rows over 3879 dates from 2006-09-22 to 2022-02-17.
# 2022-02-18 14:47:24,124 INFO KXI: Queried EOD data contains 1 rows over 1 dates from 2022-02-17 to 2022-02-17.
# 2022-02-18 14:47:24,129 INFO KXI: Amended data file contains 3879 rows over 3879 dates from 2006-09-22 to 2022-02-17.
# 2022-02-18 14:47:25,215 INFO RXI: Global Consumer Discretionary
# 2022-02-18 14:47:25,217 INFO RXI: Existing EOD data file found at __data__\RXI_EOD.csv.gz.
# 2022-02-18 14:47:25,228 INFO RXI: Existing EOD data file contains 3880 rows over 3880 dates from 2006-09-21 to 2022-02-17.
# 2022-02-18 14:47:25,304 INFO RXI: Queried EOD data contains 1 rows over 1 dates from 2022-02-17 to 2022-02-17.
# 2022-02-18 14:47:25,310 INFO RXI: Amended data file contains 3880 rows over 3880 dates from 2006-09-21 to 2022-02-17.
# 2022-02-18 14:47:26,398 INFO AAXJ: Asia ex Japan
# 2022-02-18 14:47:26,399 INFO AAXJ: Existing EOD data file found at __data__\AAXJ_EOD.csv.gz.
# 2022-02-18 14:47:26,410 INFO AAXJ: Existing EOD data file contains 3402 rows over 3402 dates from 2008-08-15 to 2022-02-17.
# 2022-02-18 14:47:26,554 INFO AAXJ: Queried EOD data contains 1 rows over 1 dates from 2022-02-17 to 2022-02-17.
# 2022-02-18 14:47:26,557 INFO AAXJ: Amended data file contains 3402 rows over 3402 dates from 2008-08-15 to 2022-02-17.
# 2022-02-18 14:47:27,643 INFO EZU: Eurozone
# 2022-02-18 14:47:27,645 INFO EZU: Existing EOD data file found at __data__\EZU_EOD.csv.gz.
# 2022-02-18 14:47:27,658 INFO EZU: Existing EOD data file contains 5424 rows over 5424 dates from 2000-07-31 to 2022-02-17.
# 2022-02-18 14:47:27,736 INFO EZU: Queried EOD data contains 1 rows over 1 dates from 2022-02-17 to 2022-02-17.
# 2022-02-18 14:47:27,740 INFO EZU: Amended data file contains 5424 rows over 5424 dates from 2000-07-31 to 2022-02-17.

# %% [markdown]
# ### Valuate the instruments

# %%
df_valuation_metrics, d_fig = batchValuation(d_instrument_data, verbose=0, printfunc=logPrint)

df_valuation_metrics
# Out:
#      ticker  r2_train train_years annualized_return currenct_price  \
# 0       IVV  0.970875     9.99726          0.134298     439.100006
# 1   3073.HK  0.916889    10.00274          0.082725      51.540001
# 2       VPL  0.890417     9.99726          0.067471      75.190002
# 3       IEV  0.780835     9.99726          0.052748      52.220001
# 4      ASEA   0.34525     9.99726          0.016434        16.0149
# 5        XT  0.952837    6.909589          0.187078      57.330002
# 6       IXG  0.889357     9.99726          0.079686      82.419998
# 7       IXJ  0.960792     9.99726          0.110999      82.510002
# 8       KXI  0.961689     9.99726          0.071468      63.099998
# 9       RXI  0.949133     9.99726          0.119109     162.649994
# 10     AAXJ  0.850795     9.99726          0.061776      82.010002
# 11      EZU  0.796432     9.99726          0.061354      46.779999
#
#     fair_price over_value_range over_value_years
# 0   410.225532         0.070387         0.524109
# 1    52.423723        -0.016857        -0.139451
# 2    77.105931        -0.024848        -0.167653
# 3    49.172989         0.061965         1.174748
# 4    14.345758         0.116351         7.079854
# 5     64.15508        -0.106384        -1.990208
# 6    77.263296         0.066742         0.837565
# 7     82.80173        -0.003523        -0.039107
# 8    60.870746         0.036623         0.512436
# 9   163.831243         -0.00721        -0.085879
# 10    81.35366         0.008068         0.130596
# 11   45.647313         0.024814         0.404439

# %% [markdown]
# ### Construct a portfolio

# %%
instruments_select = ['IVV', '3073.HK', 'VPL', 'IEV', 'ASEA']

df_portfolio = df_valuation_metrics[df_valuation_metrics['ticker'].isin(instruments_select)]
df_portfolio = addCashPortfolio(df_portfolio)
df_portfolio['portfolio_allocation'] = allocatePortfolio(df_portfolio['over_value_years'], with_cash=True)

df_portfolio
# Out:
#     ticker  r2_train train_years annualized_return currenct_price  fair_price  \
# 0      IVV  0.970875     9.99726          0.134298     439.100006  410.225532
# 1  3073.HK  0.916889    10.00274          0.082725      51.540001   52.423723
# 2      VPL  0.890417     9.99726          0.067471      75.190002   77.105931
# 3      IEV  0.780835     9.99726          0.052748      52.220001   49.172989
# 4     ASEA   0.34525     9.99726          0.016434        16.0149   14.345758
# 5     cash       NaN         NaN               NaN            NaN         NaN
#
#   over_value_range  over_value_years  portfolio_allocation
# 0         0.070387          0.524109              0.104360
# 1        -0.016857         -0.139451              0.301734
# 2        -0.024848         -0.167653              0.315661
# 3         0.061965          1.174748              0.036849
# 4         0.116351          7.079854              0.000003
# 5              NaN          0.000000              0.241393
